# %%
import pandas as pd
import os
import sqlite3

db = sqlite3.connect("Proj.db")
df = pd.read_csv('CauseOfDeath.csv')
df.to_sql("CauseOfDeath", db, if_exists="replace")

def runQuery(query):
    return pd.read_sql_query(query, db)

os.getcwd()
# Out:
# 'C:\\Users\\maris\\OneDrive\\Desktop\\Python\\PythonCodeLou'

# %%
df
# Out:
#       TIME     GEO    UNIT      SEX    AGE  \
# 0     2001  France  Number    Males  Total
# 1     2001  France  Number    Males  Total
# 2     2001  France  Number    Males  Total
# 3     2001  France  Number    Males  Total
# 4     2001  France  Number    Males  Total
# ...    ...     ...     ...      ...    ...
# 1051  2008  France  Number  Females  Total
# 1052  2008  France  Number  Females  Total
# 1053  2008  France  Number  Females  Total
# 1054  2008  France  Number  Females  Total
# 1055  2008  France  Number  Females  Total
#
#                                                   ICD10    Value  \
# 0       All causes of death (A00-Y89) excluding S00-T98  277 858
# 1     Certain infectious and parasitic diseases (A00...    5 347
# 2                                          Tuberculosis      545
# 3                               Meningococcal infection       30
# 4                                       Viral hepatitis      471
# ...                                                 ...      ...
# 1051                                              Falls    2 815
# 1052  Accidental poisoning by and exposure to noxiou...      630
# 1053                              Intentional self-harm    2 768
# 1054                                            Assault      166
# 1055                       Event of undetermined intent       68
#
#       Flag and Footnotes
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 1051                 NaN
# 1052                 NaN
# 1053                 NaN
# 1054                 NaN
# 1055                 NaN
#
# [1056 rows x 8 columns]

# %%
query = """
SELECT * 
FROM sqlite_master
ORDER BY name;
"""
runQuery(query)
# Out:
#     type                   name      tbl_name  rootpage  \
# 0  table           CauseOfDeath  CauseOfDeath         2
# 1  index  ix_CauseOfDeath_index  CauseOfDeath         3
#
#                                                  sql
# 0  CREATE TABLE "CauseOfDeath" (\n"index" INTEGER...
# 1  CREATE INDEX "ix_CauseOfDeath_index"ON "CauseO...

# %%
query = """
SELECT * 
FROM CauseOfDeath;
"""
runQuery(query)
# Out:
#       index  TIME     GEO    UNIT      SEX    AGE  \
# 0         0  2001  France  Number    Males  Total
# 1         1  2001  France  Number    Males  Total
# 2         2  2001  France  Number    Males  Total
# 3         3  2001  France  Number    Males  Total
# 4         4  2001  France  Number    Males  Total
# ...     ...   ...     ...     ...      ...    ...
# 1051   1051  2008  France  Number  Females  Total
# 1052   1052  2008  France  Number  Females  Total
# 1053   1053  2008  France  Number  Females  Total
# 1054   1054  2008  France  Number  Females  Total
# 1055   1055  2008  France  Number  Females  Total
#
#                                                   ICD10    Value  \
# 0       All causes of death (A00-Y89) excluding S00-T98  277 858
# 1     Certain infectious and parasitic diseases (A00...    5 347
# 2                                          Tuberculosis      545
# 3                               Meningococcal infection       30
# 4                                       Viral hepatitis      471
# ...                                                 ...      ...
# 1051                                              Falls    2 815
# 1052  Accidental poisoning by and exposure to noxiou...      630
# 1053                              Intentional self-harm    2 768
# 1054                                            Assault      166
# 1055                       Event of undetermined intent       68
#
#      Flag and Footnotes
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# ...                 ...
# 1051               None
# 1052               None
# 1053               None
# 1054               None
# 1055               None
#
# [1056 rows x 9 columns]
